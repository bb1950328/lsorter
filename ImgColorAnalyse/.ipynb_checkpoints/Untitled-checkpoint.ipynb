# %%
import PIL
import numpy
from PIL import Image

# %%
def filename_crop_array(filename, coords, show=False):
    img = Image.open(filename)
    img = img.crop(coords)
    if show:
        img.show()
    return img.load()

# %%
pxa = filename_crop_array("IMG10.JPG", (200, 100, 600, 500))

# %%
pxa[100, 100]#ein pinkes pixel
# Out:
# (189, 84, 89)

# %%
for x in range(399):
    for y in range(399):
        p = pxa[x, y]
        if (180<= p[0] <= 200) and (75<= p[1] <= 95) and (80<= p[2] <= 100):
            pxa[x, y] = (255, 255, 255)

# %%
import matplotlib.pyplot
# %matplotlib inline
import time

# %%
def array_to_img(arr, size):
    img = Image.new("RGB", size)
    for x in range(size[0]):
        for y in range(size[1]):
            #print(arr[x, y])
            img.putpixel((x, y), arr[x, y])
    return(img)

# %%
def clean_analyse_img(filename):
    #pxa = filename_crop_array(filename, (200, 100, 600, 500))
    img = Image.open(filename)
    cnt=0
    #for x in range(399):
    #    for y in range(399):
    #        p = pxa[x, y]
    #        if (170<= p[0] <= 210) and (60<= p[1] <= 95) and (70<= p[2] <= 100):
    #            pxa[x, y] = (255, 255, 255)
    #            cnt+=1
    #ni = array_to_img(pxa, (400, 400))
    #ni = Image.fromarray(pxa)
    #ni.show()
    print(filename, ":\tMain color is:", pxstats_str(img))
    #return ni
    return

# %%
pxshowrgb(ni).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e3da4491f391> in <module>()
# ----> 1 pxshowrgb(ni).show()
#
# NameError: name 'pxshowrgb' is not defined

# %%
pxstats(ni)

# %%
def pxstats(img):#[anz_rot, anz_gruen, anz_blue]
    stat = [0, 0, 0]
    for x in range(img.size[0]):
        for y in range(img.size[1]):
            rgb = img.getpixel((x, y))
            r = rgb[0]
            g = rgb[1]
            b = rgb[2]
            if (r-20>= g) and (r-20>= b) and sum(rgb)>200:
                stat[0] +=1
            elif (g-20>= r) and (g-20>= b):
                stat[1] +=1
            elif (b-20>= r) and (b-20>= g):
                stat[2] +=1
    return stat

def pxstats2(img):#[anz_rot, anz_gruen, anz_blue]
    stat = [0, 0, 0]
    bt = 30
    for x in range(0, 800, 4):
        for y in range(0, 600, 4):
            #print(img.size)
            #print((400-x, 300-y))
            rgb = img.getpixel((x, y))
            r = rgb[0]
            g = rgb[1]
            b = rgb[2]
            if (r-bt>= g) and (r-bt>= b):# and sum(rgb)>200:
                stat[0] +=1
            elif (g-bt>= r) and (g-bt>= b):
                stat[1] +=1
            elif (b-bt>= r) and (b-bt>= g):
                stat[2] +=1
            #check if the color is already clear:
            tr = 400
            if stat[0]-tr>stat[1] and stat[0]-tr>stat[2]:
                return [1, 0, 0]
            elif stat[1]-tr>stat[0] and stat[1]-tr>stat[2]:
                return [0, 1, 0]
            elif stat[2]-tr>stat[0] and stat[2]-tr>stat[1]:
                return [0, 0, 1]
    return stat

def pxstats_str(img):
    stat = pxstats2(img)
    #print(stat)
    r = stat[0]
    g = stat[1]
    b = stat[2]
    if r>g and r>b:
        return "Red"
    elif g>r and g>b:
        return "Green"
    else:
        return "Blue"

def pxshowrgb(img):
    img = img.copy()
    for x in range(img.size[0]):
        for y in range(img.size[1]):
            rgb = img.getpixel((x, y))
            r = rgb[0]
            g = rgb[1]
            b = rgb[2]
            if (r-20>= g) and (r-20>= b) and sum(rgb)>200:
                img.putpixel((x, y), (255, 0, 0))
            elif (g-20>= r) and (g-20>= b):
                img.putpixel((x, y), (0, 255, 0))
            elif (b-20>= r) and (b-20>= g):
                img.putpixel((x, y), (0, 0, 255))
    return img

# %%
start = time.perf_counter()
for i in range(10, 45):
    fn = "DSC"+str(i)+".JPG"
    clean_analyse_img(fn)
stop = time.perf_counter()
print((stop-start)/35)

# %%
import numpy
import cv2
start = time.perf_counter()


ret = False
while not ret:
    cap = cv2.VideoCapture(0)
    ret, frame = cap.read()
    print(ret)
# Capture frame-by-frame

#print(ret)

#sub = Image.fromarray(frame)
#sub = sub.convert("RGB")
#data = np.array(frame) 
#red, green, blue = data[:,:,0], data[:,:,1], data[:,:,2]
#data = np.array((data[:,:,2], data[:,:,0], data[:,:,1]))
#frame = data.transpose()
#frame = numpy.rot90(frame)
#frame = numpy.rot90(frame)
#frame = numpy.rot90(frame)

#sub = Image.fromarray(data)
# Our operations on the frame come here
#frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
matplotlib.pyplot.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
stop = time.perf_counter()
print((stop-start))
#del frame
#del data
# Display the resulting frame
#cv2.imshow('frame',frame)

# When everything done, release the capture
#cap.release()
#cv2.destroyAllWindows()
# Out:
# False
# True
# 0.7423581660004857

# %%
def img_cap_show():
    start = time.perf_counter()
    cap = cv2.VideoCapture(0)
    ret, frame = cap.read()
    print(frame)
    frame = numpy.array(frame)
    print(frame.ndim)
    b, g, r = frame[:,:,0], frame[:,:,1], frame[:,:,2]
    frame = numpy.dstack((r, b, g))
    matplotlib.pyplot.imshow(frame)
    stop = time.perf_counter()
    print((stop-start))

# %%
img_cap_show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bc3c07564ee0> in <module>()
# ----> 1 img_cap_show()
#
# <ipython-input-10-724de097747a> in img_cap_show()
#       1 def img_cap_show():
#       2     start = time.perf_counter()
# ----> 3     cap = cv2.VideoCapture(0)
#       4     ret, frame = cap.read()
#       5     print(frame)
#
# NameError: name 'cv2' is not defined
