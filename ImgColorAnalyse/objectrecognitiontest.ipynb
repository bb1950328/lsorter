# %%
def capture_img():
    try:
        ret = False
        while not ret:
            cap = cv2.VideoCapture(0)
            ret, frame = cap.read()
            print(ret)
        return frame
    #matplotlib.pyplot.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    except:
        cap.release()
        return

# %%
import cv2, time

def diffImg(t0, t1, t2):
  d1 = cv2.absdiff(t2, t1)
  d2 = cv2.absdiff(t1, t0)
  return cv2.bitwise_and(d1, d2)

#cam = cv2.VideoCapture(0)

winName = "Movement Indicator"
cv2.namedWindow(winName)

# Read three images first:
t_minus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
t = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
t_plus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)

while True:
  start = time.perf_counter()
  dimg=diffImg(t_minus, t, t_plus)
  cv2.imshow( winName, dimg)
  print(cv2.countNonZero(dimg))

  # Read next image
  t_minus = t
  t = t_plus
  t_plus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
  stop = time.perf_counter()
  print("T:", (stop-start))
  key = cv2.waitKey(10)
  if key == 27:
    cv2.destroyWindow(winName)
    break

print("Goodbye")
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
winName = "Laplacian"
cv2.namedWindow(winName)
while True:
    cv2.imshow(winName, cv2.Laplacian(capture_img(), cv2.CV_64F))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-1f2d1a9da870> in <module>()
#       2 cv2.namedWindow(winName)
#       3 while True:
# ----> 4     cv2.imshow(winName, cv2.Laplacian(capture_img(), cv2.CV_64F))
#
# error: /io/opencv/modules/core/src/matrix.cpp:991: error: (-215) dims <= 2 && step[0] > 0 in function locateROI
