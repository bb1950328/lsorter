# %%
def capture_img():
    try:
        ret = False
        while not ret:
            cap = cv2.VideoCapture(0)
            ret, frame = cap.read()
            print(ret)
        return frame
    #matplotlib.pyplot.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    except:
        cap.release()
        return

# %%
import cv2, time

def diffImg(t0, t1, t2):
  d1 = cv2.absdiff(t2, t1)
  d2 = cv2.absdiff(t1, t0)
  return cv2.bitwise_and(d1, d2)

#cam = cv2.VideoCapture(0)

winName = "Movement Indicator"
cv2.namedWindow(winName)

# Read three images first:
t_minus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
t = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
t_plus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)

while True:
  start = time.perf_counter()
  dimg=diffImg(t_minus, t, t_plus)
  cv2.imshow( winName, dimg)
  print(cv2.countNonZero(dimg))

  # Read next image
  t_minus = t
  t = t_plus
  t_plus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
  stop = time.perf_counter()
  print("T:", (stop-start))
  key = cv2.waitKey(10)
  if key == 27:
    cv2.destroyWindow(winName)
    break

print("Goodbye")
# Out:
# True
# True
# True
# 120580
# True
# T: 0.3999197800003458
# 101747
# True
# T: 0.3959445050004433
# 99883
# True
# T: 0.41630110100049933
# 99962
# True
# T: 0.4068610809990787
# 97700
# True
# T: 0.39925013100037177
# 97599
# True
# T: 0.4220772959997703
# 101223
# True
# T: 0.3876554859998578
# 99252
# True
# T: 0.3889064619997953
# 104914
# True
# T: 0.400525805000143
# 103418
# True
# T: 0.39829169499898853
# 104606
# True
# T: 0.3905954869987909
# 100671
# True
# T: 0.38949810699887166
# 95583
# True
# T: 0.392021489000399
# 97856
# True
# T: 0.3911309289997007
# 93436
# True
# T: 0.3912991510005668
# 92184
# True
# T: 0.4042153730006248
# 92355
# True
# T: 0.39373701099975733
# 100900
# True
# T: 0.3931615559995407
# 115554
# True
# T: 0.39343715500035614
# 104126
# True
# T: 0.39171162899947376
# 98978
# True
# T: 0.40589925200038124
# 97920
# True
# T: 0.3951038579998567
# 119921
# True
# T: 0.4137956070007931
# 118283
# True
# T: 0.394896597999832
# 114525
# True
# T: 0.39757485399968573
# 104999
# True
# T: 0.3939253110002028
# 104208
# True
# T: 0.39276214500023343
# 107009
# True
# T: 0.3933278460008296
# 113479
# True
# T: 0.39636589499968977
# 111731
# True
# T: 0.4038570820011955
# 113620
# True
# T: 0.4169860929996503
# 103505
# True
# T: 0.3933379159989272
# 101640
# True
# T: 0.4077588000000105
# 97682
# True
# T: 0.4225001679988054
# 98465
# True
# T: 0.44560884199927386
# 98491
# True
# T: 0.4125854989997606
# 94388
# True
# T: 0.4109958259996347
# 93588
# True
# T: 0.39057624700035376
# 92234
# True
# T: 0.3978102189994388
# 93502
# True
# T: 0.395133732999966
# 88582
# True
# T: 0.39281316499909735
# 89212
# True
# T: 0.3892333759995381
# 91217
# True
# T: 0.39019797899891273
# 92304
# True
# T: 0.3900291179998021
# 91868
# True
# T: 0.39660604399978183
# 95827
# True
# T: 0.39187671299987414
# 89415
# True
# T: 0.3934708219985623
# 88932
# True
# T: 0.3993325810006354
# 89583
# True
# T: 0.40102707400001236
# 89174
# True
# T: 0.3899784829991404
# 88991
# True
# T: 0.3938852030005364
# 88661
# True
# T: 0.3940032530008466
# 88756
# True
# T: 0.3941973960008909
# 89593
# True
# T: 0.38976444299987634
# 89259
# True
# T: 0.39653825599998527
# 87782
# True
# T: 0.39340102700043644
# 87835
# True
# T: 0.390429472001415
# 87805
# True
# T: 0.39202906399987114
# 88109
# True
# T: 0.3900151220004773
# 88764
# True
# T: 0.3977595249998558
# 88502
# True
# T: 0.39094692199978454
# 89864
# True
# T: 0.394689719998496
# 88878
# True
# T: 0.3896501979997993
# 87108
# True
# T: 0.3936717819997284
# 91378
# True
# T: 0.3969693830003962
# 113559
# True
# T: 0.3933425390005141
# 117797
# True
# T: 0.3943174230007571
# 111506
# True
# T: 0.3920626989984157
# 112201
# True
# T: 0.39399425799820165
# 117848
# True
# T: 0.3922627759984607
# 127046
# True
# T: 0.390951811999912
# 108701
# True
# T: 0.3985230969992699
# 103677
# True
# T: 0.3903581079994183
# 95558
# True
# T: 0.4045191290006187
# 93137
# True
# T: 0.3912805549989571
# 93147
# True
# T: 0.39230138899984013
# 92367
# True
# T: 0.39369319199977326
# 91810
# True
# T: 0.39699866399860184
# 93232
# True
# T: 0.39020788699963305
# 93675
# True
# T: 0.3956893679987843
# 93802
# True
# T: 0.38979032300085237
# 94625
# True
# T: 0.39109099000052083
# 95924
# True
# T: 0.3954412049988605
# 103998
# True
# T: 0.3926224580009148
# 101503
# True
# T: 0.403976165000131
# 102142
# True
# T: 0.3948389870001847
# 99512
# True
# T: 0.3893224329985969
# 100522
# True
# T: 0.39539294199857977
# 101044
# True
# T: 0.3907665749993612
# 106518
# True
# T: 0.39102022999941255
# 99176
# True
# T: 0.393807143000231
# 92425
# True
# T: 0.3967797969999083
# 89504
# True
# T: 0.3914616219990421
# 89173
# True
# T: 0.38921931400000176
# 89105
# True
# T: 0.38995801500095695
# 86442
# True
# T: 0.39177094399929047
# 86405
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-9608660c6ce5> in <module>()
#      25   t_minus = t
#      26   t = t_plus
# ---> 27   t_plus = cv2.cvtColor(capture_img(), cv2.COLOR_RGB2GRAY)
#      28   stop = time.perf_counter()
#      29   print("T:", (stop-start))
#
# error: /io/opencv/modules/imgproc/src/color.cpp:11111: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
winName = "Laplacian"
cv2.namedWindow(winName)
while True:
    cv2.imshow(winName, cv2.Laplacian(capture_img(), cv2.CV_64F))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-1f2d1a9da870> in <module>()
#       2 cv2.namedWindow(winName)
#       3 while True:
# ----> 4     cv2.imshow(winName, cv2.Laplacian(capture_img(), cv2.CV_64F))
#
# error: /io/opencv/modules/core/src/matrix.cpp:991: error: (-215) dims <= 2 && step[0] > 0 in function locateROI
